# %%
print("hello world")
# Out:
# hello world

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.6.3-cp310-cp310-win_amd64.whl (7.2 MB)
# Requirement already satisfied: cycler>=0.10 in e:\python\datavisualizations\dashboard\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\python\datavisualizations\dashboard\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in e:\python\datavisualizations\dashboard\lib\site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: pyparsing>=2.2.1 in e:\python\datavisualizations\dashboard\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in e:\python\datavisualizations\dashboard\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in e:\python\datavisualizations\dashboard\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\python\datavisualizations\dashboard\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in e:\python\datavisualizations\dashboard\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in e:\python\datavisualizations\dashboard\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: six>=1.5 in e:\python\datavisualizations\dashboard\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: matplotlib
# WARNING: Ignoring invalid distribution -atplotlib (e:\python\datavisualizations\dashboard\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (e:\python\datavisualizations\dashboard\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (e:\python\datavisualizations\dashboard\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'E:\\python\\dataVisualizations\\dashboard\\Lib\\site-packages\\matplotlib\\_c_internal_utils.cp310-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -atplotlib (e:\python\datavisualizations\dashboard\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (e:\python\datavisualizations\dashboard\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (e:\python\datavisualizations\dashboard\lib\site-packages)

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

url = 'https://www.census2011.co.in/literacy.php'
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

r = requests.get(url, headers=header)

dfs = pd.read_html(r.text)
#df = pd.read_html(url , match="table table2 filter table-striped table-hover ")
print(f'Total tables: {len(dfs)}')
df = dfs[0]

print(df.columns)
df.drop(columns =['#'],inplace=True)
df.head(5)
# Out:
# Total tables: 1
# Index(['#', 'State', 'Literacy', 'Male', 'Female', '% Change'], dtype='object')
#          State  Literacy   Male  Female  % Change
# 0        India     74.04  82.14   65.46      8.66
# 1       Kerala     94.00  96.11   92.07      3.14
# 2  Lakshadweep     91.85  95.56   87.95      5.19
# 3      Mizoram     91.33  93.35   89.27      2.53
# 4          Goa     88.70  92.65   84.66      6.69

# %%
#Reference: https://colab.research.google.com/drive/1lKuaZUp8LggiDFbct0-DcUDMMYdvO4Tp?usp=sharing#scrollTo=sBkAKOCTYOek

def color_title(labels, colors, textprops = {'size':'large'}, ax = None, y = 1.013,
               precision = 10**-2):
     
    "Creates a centered title with multiple colors. Don't change axes limits afterwards."
        
    if ax == None:
        ax = plt.gca()
        
    plt.gcf().canvas.draw()
    transform = ax.transAxes # use axes coords
    
    # initial params
    xT = 0 # where the text ends in x-axis coords
    shift = 0 # where the text starts
    
    # for text objects
    text = dict()

    while (np.abs(shift - (1-xT)) > precision) and (shift <= xT) :         
        x_pos = shift 
        
        for label, col in zip(labels, colors):

            try:
                text[label].remove()
            except KeyError:
                pass
            
            text[label] = ax.text(x_pos, y, label, 
                        transform = transform, 
                        ha = 'left',
                        color = col,
                                            **textprops)
            
            x_pos = text[label].get_window_extent()\
                   .transformed(transform.inverted()).x1
            
        xT = x_pos # where all text ends
        
        shift += precision/2 # increase for next iteration
      
        if x_pos > 1: # guardrail 
            break

# %%
# Create playground
fig, ax = plt.subplots(figsize=(13, 8))

# Visuals
df.plot.scatter(x='Male',  y='State', ax=ax, color='#1E1E1E', s=60)
df.plot.scatter(x='Female', y='State', ax=ax,c='#FC7D0B', s=60)
ax.hlines(y= range(0,len(df.index)), xmin=df['Female'], xmax=df['Male'], linewidth=5, color='#BDBDBD', zorder=0)


# Background and remove noise
ax.set_facecolor('#F5F5F5')
ax.spines[['bottom', 'top', 'left', 'right']].set_visible(False)
ax.tick_params(axis='both', length=0)
ax.set(ylabel=None)
ax.set(xlabel=None)

# Title color
label_list = ['% of Literacy ', 'Female', ' and ', 'Male ', 'Statewise']
colors = ['#969FA7', '#FC7D0B', '#969FA7', '#1E1E1E', '#969FA7']
color_title(label_list, colors)

#plt.text(-10,-1,'Source: Census India 2011', c='#969FA7');
plt.text(x=50, y=-5,s='Source: Census India 2011', c='#969FA7')
plt.show()

#plt.savefig('LiteracyIndiaStatewiseGender.png', dpi=300, facecolor='#F5F5F5',bbox_inches='tight' )
